# %% [markdown]
# ### Feriados e Dias Úteis com Python

# %%
import holidays

feriados = holidays.country_holidays("BR", subdiv="RJ")
feriados_2024 = feriados["2024-01-01":"2024-12-31"]

for feriado in feriados_2024:
    print(feriado)
# Out:
# 2024-01-01
# 2024-03-29
# 2024-04-21
# 2024-04-23
# 2024-05-01
# 2024-09-07
# 2024-10-12
# 2024-11-02
# 2024-11-15
# 2024-11-20
# 2024-12-25

# %% [markdown]
# ### Outro Jeito Em Brasil

# %%
import pandas_market_calendars as mcal

calendario = mcal.get_calendar("BMF")
dias_negociacao = calendario.schedule(start_date="2024-01-01", end_date="2024-12-31")
display(dias_negociacao)
# Out:
#                          market_open              market_close
# 2024-01-02 2024-01-02 13:00:00+00:00 2024-01-02 20:00:00+00:00
# 2024-01-03 2024-01-03 13:00:00+00:00 2024-01-03 20:00:00+00:00
# 2024-01-04 2024-01-04 13:00:00+00:00 2024-01-04 20:00:00+00:00
# 2024-01-05 2024-01-05 13:00:00+00:00 2024-01-05 20:00:00+00:00
# 2024-01-08 2024-01-08 13:00:00+00:00 2024-01-08 20:00:00+00:00
# ...                              ...                       ...
# 2024-12-20 2024-12-20 13:00:00+00:00 2024-12-20 20:00:00+00:00
# 2024-12-23 2024-12-23 13:00:00+00:00 2024-12-23 20:00:00+00:00
# 2024-12-26 2024-12-26 13:00:00+00:00 2024-12-26 20:00:00+00:00
# 2024-12-27 2024-12-27 13:00:00+00:00 2024-12-27 20:00:00+00:00
# 2024-12-30 2024-12-30 13:00:00+00:00 2024-12-30 20:00:00+00:00
#
# [251 rows x 2 columns]

# %% [markdown]
# ### Outro Jeito Mas Em São Paulo

# %%
import pandas_market_calendars as mcal

dias_negociacao2 = calendario.schedule(start_date="2025-01-01", end_date="2026-01-01", tz="America/Sao_Paulo")
display(dias_negociacao2)
# Out:
#                          market_open              market_close
# 2025-01-02 2025-01-02 10:00:00-03:00 2025-01-02 17:00:00-03:00
# 2025-01-03 2025-01-03 10:00:00-03:00 2025-01-03 17:00:00-03:00
# 2025-01-06 2025-01-06 10:00:00-03:00 2025-01-06 17:00:00-03:00
# 2025-01-07 2025-01-07 10:00:00-03:00 2025-01-07 17:00:00-03:00
# 2025-01-08 2025-01-08 10:00:00-03:00 2025-01-08 17:00:00-03:00
# ...                              ...                       ...
# 2025-12-22 2025-12-22 10:00:00-03:00 2025-12-22 17:00:00-03:00
# 2025-12-23 2025-12-23 10:00:00-03:00 2025-12-23 17:00:00-03:00
# 2025-12-26 2025-12-26 10:00:00-03:00 2025-12-26 17:00:00-03:00
# 2025-12-29 2025-12-29 10:00:00-03:00 2025-12-29 17:00:00-03:00
# 2025-12-30 2025-12-30 10:00:00-03:00 2025-12-30 17:00:00-03:00
#
# [250 rows x 2 columns]
