# %% [markdown]
# ### 10 Temas de Python Que Eu Tenho Que Saber :

# %% [markdown]
#     1 Elementos Básicos :
#     variáveis, strings, inteiros, floats, etc ...

# %% [markdown]
#     2 Operações Com Elementos Básicos

# %% [markdown]
#     3 Condicionais e Comparações :
#     if, else, ect ...

# %% [markdown]
#     4 Estruturas De Repetição

# %% [markdown]
#     5 Iterables :
#     listas, tuplas, dicionários e, talvez, sets

# %% [markdown]
#     6 Trabalhar Com Bibliotecas e Módulos

# %% [markdown]
#     7

# %% [markdown]
#     8

# %% [markdown]
#     9

# %% [markdown]
#     10
