# %% [markdown]
# ### - Adição

# %%
print(2 + 2)
# Out:
# 4

# %% [markdown]
# ### - Subtração

# %%
print(2 - 2)
# Out:
# 0

# %% [markdown]
# ### - Multiplicação

# %%
print(2 * 5)
# Out:
# 10

# %% [markdown]
# ### - Divisão

# %%
print(2 / 5)
# Out:
# 0.4

# %% [markdown]
# ### - Potenciação

# %%
print(2 ** 5)

# %% [markdown]
# ### - Raiz Quadrada

# %%
print(2 ** (1/2))
# Out:
# 3.0

# %% [markdown]
# ### - Mod

# %%
print(7 % 3)
